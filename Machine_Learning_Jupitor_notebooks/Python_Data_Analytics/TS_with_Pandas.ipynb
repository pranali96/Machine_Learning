# %%
import pandas as pd

# %%
df=pd.read_csv("HistoricalQuotes.csv")

# %%
df
# Out:
#            date   close         volume     open     high     low
# 0    2019/08/10  200.99     24,619,446  201.230  202.760  199.29
# 1    2019/08/09  200.99  24619750.0000  201.300  202.760  199.29
# 2    2019/08/08  203.43  27009520.0000  200.200  203.530  199.39
# 3    2019/08/07  199.04  33364400.0000  195.410  199.560  193.82
# 4    2019/08/06  197.00  35824790.0000  196.310  198.067  194.04
# ..          ...     ...            ...      ...      ...     ...
# 248  2018/08/15  210.24  28595230.0000  209.220  210.740  208.33
# 249  2018/08/14  209.75  20679270.0000  210.155  210.560  208.26
# 250  2018/08/13  208.87  25864510.0000  207.700  210.952  207.70
# 251  2018/08/10  207.53  24592460.0000  207.360  209.100  206.67
# 252  2018/08/09  208.88  23389530.0000  207.280  209.780  207.20
#
# [253 rows x 6 columns]

# %%
df.head()
# Out:
#          date   close         volume    open     high     low
# 0  2019/08/10  200.99     24,619,446  201.23  202.760  199.29
# 1  2019/08/09  200.99  24619750.0000  201.30  202.760  199.29
# 2  2019/08/08  203.43  27009520.0000  200.20  203.530  199.39
# 3  2019/08/07  199.04  33364400.0000  195.41  199.560  193.82
# 4  2019/08/06  197.00  35824790.0000  196.31  198.067  194.04

# %%
type(df.date[0])
# Out:
# str

# %%
df=pd.read_csv("HistoricalQuotes.csv", parse_dates=["date"])

# %%
type(df.date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.head()
# Out:
#         date   close         volume    open     high     low
# 0 2019-08-10  200.99     24,619,446  201.23  202.760  199.29
# 1 2019-08-09  200.99  24619750.0000  201.30  202.760  199.29
# 2 2019-08-08  203.43  27009520.0000  200.20  203.530  199.39
# 3 2019-08-07  199.04  33364400.0000  195.41  199.560  193.82
# 4 2019-08-06  197.00  35824790.0000  196.31  198.067  194.04

# %%
df=pd.read_csv("HistoricalQuotes.csv", parse_dates=["date"], index_col=['date'])

# %%
df.volume = df.volume.str.replace(",","").astype(float)

# %%
df.sort_index(inplace=True)

# %%
df.index
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-10', '2018-08-13', '2018-08-14',
#                '2018-08-15', '2018-08-16', '2018-08-17', '2018-08-20',
#                '2018-08-21', '2018-08-22',
#                ...
#                '2019-07-30', '2019-07-31', '2019-08-01', '2019-08-02',
#                '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08',
#                '2019-08-09', '2019-08-10'],
#               dtype='datetime64[ns]', name='date', length=253, freq=None)

# %%
df['2019-08']
# Out:
#              close      volume    open     high       low
# date
# 2019-08-01  208.43  54017920.0  213.90  218.030  206.7435
# 2019-08-02  204.02  40862120.0  205.53  206.430  201.6300
# 2019-08-05  193.34  52392970.0  197.99  198.649  192.5800
# 2019-08-06  197.00  35824790.0  196.31  198.067  194.0400
# 2019-08-07  199.04  33364400.0  195.41  199.560  193.8200
# 2019-08-08  203.43  27009520.0  200.20  203.530  199.3900
# 2019-08-09  200.99  24619750.0  201.30  202.760  199.2900
# 2019-08-10  200.99  24619446.0  201.23  202.760  199.2900

# %%
df['2019-08'].close
# Out:
# date
# 2019-08-01    208.43
# 2019-08-02    204.02
# 2019-08-05    193.34
# 2019-08-06    197.00
# 2019-08-07    199.04
# 2019-08-08    203.43
# 2019-08-09    200.99
# 2019-08-10    200.99
# Name: close, dtype: float64

# %%
df['2018'].close
# Out:
# date
# 2018-08-09    208.88
# 2018-08-10    207.53
# 2018-08-13    208.87
# 2018-08-14    209.75
# 2018-08-15    210.24
#                ...
# 2018-12-24    146.83
# 2018-12-26    157.17
# 2018-12-27    156.15
# 2018-12-28    156.23
# 2018-12-31    157.74
# Name: close, Length: 99, dtype: float64

# %%
df['2019-08'].close.mean()
# Out:
# 200.905

# %%
df['2019-08'].close.median()
# Out:
# 200.99

# %%
df['2019-08'].close.mode()
# Out:
# 0    200.99
# dtype: float64

# %%
df.loc['2019-08-02']
# Out:
# close          204.02
# volume    40862120.00
# open           205.53
# high           206.43
# low            201.63
# Name: 2019-08-02 00:00:00, dtype: float64

# %%
df['2019-07-09':'2019-08-09'] # Time :: count ticks from midnight 1/1/1971
# Out:
#              close      volume    open      high       low
# date
# 2019-07-09  201.24  20578020.0  199.20  201.5100  198.8100
# 2019-07-10  203.23  17897140.0  201.85  203.7300  201.5600
# 2019-07-11  201.75  20191840.0  203.31  204.3900  201.7100
# 2019-07-12  203.30  17595210.0  202.45  204.0000  202.2000
# 2019-07-15  205.21  16947420.0  204.09  205.8700  204.0000
# 2019-07-16  204.50  16866820.0  204.59  206.1100  203.5000
# 2019-07-17  203.35  14107450.0  204.05  205.0915  203.2700
# 2019-07-18  205.66  18582160.0  204.00  205.8800  203.7000
# 2019-07-19  202.59  20929310.0  205.79  206.5000  202.3600
# 2019-07-22  207.22  22277930.0  203.65  207.2300  203.6100
# 2019-07-23  208.84  18355210.0  208.46  208.9100  207.2900
# 2019-07-24  208.67  14991570.0  207.67  209.1500  207.1700
# 2019-07-25  207.02  13909560.0  208.89  209.2400  206.7300
# 2019-07-26  207.74  17618870.0  207.48  209.7300  207.1400
# 2019-07-29  209.68  21673390.0  208.46  210.6400  208.4400
# 2019-07-30  208.78  33935720.0  208.76  210.1600  207.3100
# 2019-07-31  213.04  69281360.0  216.42  221.3700  211.3000
# 2019-08-01  208.43  54017920.0  213.90  218.0300  206.7435
# 2019-08-02  204.02  40862120.0  205.53  206.4300  201.6300
# 2019-08-05  193.34  52392970.0  197.99  198.6490  192.5800
# 2019-08-06  197.00  35824790.0  196.31  198.0670  194.0400
# 2019-08-07  199.04  33364400.0  195.41  199.5600  193.8200
# 2019-08-08  203.43  27009520.0  200.20  203.5300  199.3900
# 2019-08-09  200.99  24619750.0  201.30  202.7600  199.2900

# %%
list(df.close.resample("M"))
# Out:
# [(Timestamp('2018-08-31 00:00:00', freq='M'),
#   date
#   2018-08-09    208.88
#   2018-08-10    207.53
#   2018-08-13    208.87
#   2018-08-14    209.75
#   2018-08-15    210.24
#   2018-08-16    213.32
#   2018-08-17    217.58
#   2018-08-20    215.46
#   2018-08-21    215.04
#   2018-08-22    215.05
#   2018-08-23    215.49
#   2018-08-24    216.16
#   2018-08-27    217.94
#   2018-08-28    219.70
#   2018-08-29    222.98
#   2018-08-30    225.03
#   2018-08-31    227.63
#   Name: close, dtype: float64),
#  (Timestamp('2018-09-30 00:00:00', freq='M'),
#   date
#   2018-09-04    228.36
#   2018-09-05    226.87
#   2018-09-06    223.10
#   2018-09-07    221.30
#   2018-09-10    218.33
#   2018-09-11    223.85
#   2018-09-12    221.07
#   2018-09-13    226.41
#   2018-09-14    223.84
#   2018-09-17    217.88
#   2018-09-18    218.24
#   2018-09-19    218.37
#   2018-09-20    220.03
#   2018-09-21    217.66
#   2018-09-24    220.79
#   2018-09-25    222.19
#   2018-09-26    220.42
#   2018-09-27    224.95
#   2018-09-28    225.74
#   Name: close, dtype: float64),
#  (Timestamp('2018-10-31 00:00:00', freq='M'),
#   date
#   2018-10-01    227.26
#   2018-10-02    229.28
#   2018-10-03    232.07
#   2018-10-04    227.99
#   2018-10-05    224.29
#   2018-10-08    223.77
#   2018-10-09    226.87
#   2018-10-10    216.36
#   2018-10-11    214.45
#   2018-10-12    222.11
#   2018-10-15    217.36
#   2018-10-16    222.15
#   2018-10-17    221.19
#   2018-10-18    216.02
#   2018-10-19    219.31
#   2018-10-22    220.65
#   2018-10-23    222.73
#   2018-10-24    215.09
#   2018-10-25    219.80
#   2018-10-26    216.30
#   2018-10-29    212.24
#   2018-10-30    213.30
#   2018-10-31    218.86
#   Name: close, dtype: float64),
#  (Timestamp('2018-11-30 00:00:00', freq='M'),
#   date
#   2018-11-01    222.22
#   2018-11-02    207.48
#   2018-11-05    201.59
#   2018-11-06    203.77
#   2018-11-07    209.95
#   2018-11-08    208.49
#   2018-11-09    204.47
#   2018-11-12    194.17
#   2018-11-13    192.23
#   2018-11-14    186.80
#   2018-11-15    191.41
#   2018-11-16    193.53
#   2018-11-19    185.86
#   2018-11-20    176.98
#   2018-11-21    176.78
#   2018-11-23    172.29
#   2018-11-26    174.62
#   2018-11-27    174.24
#   2018-11-28    180.94
#   2018-11-29    179.55
#   2018-11-30    178.58
#   Name: close, dtype: float64),
#  (Timestamp('2018-12-31 00:00:00', freq='M'),
#   date
#   2018-12-03    184.82
#   2018-12-04    176.69
#   2018-12-06    174.72
#   2018-12-07    168.49
#   2018-12-10    169.60
#   2018-12-11    168.63
#   2018-12-12    169.10
#   2018-12-13    170.95
#   2018-12-14    165.48
#   2018-12-17    163.94
#   2018-12-18    166.07
#   2018-12-19    160.89
#   2018-12-20    156.83
#   2018-12-21    150.73
#   2018-12-24    146.83
#   2018-12-26    157.17
#   2018-12-27    156.15
#   2018-12-28    156.23
#   2018-12-31    157.74
#   Name: close, dtype: float64),
#  (Timestamp('2019-01-31 00:00:00', freq='M'),
#   date
#   2019-01-02    157.92
#   2019-01-03    142.19
#   2019-01-04    148.26
#   2019-01-07    147.93
#   2019-01-08    150.75
#   2019-01-09    153.31
#   2019-01-10    153.80
#   2019-01-11    152.29
#   2019-01-14    150.00
#   2019-01-15    153.07
#   2019-01-16    154.94
#   2019-01-17    155.86
#   2019-01-18    156.82
#   2019-01-22    153.30
#   2019-01-23    153.92
#   2019-01-24    152.70
#   2019-01-25    157.76
#   2019-01-28    156.30
#   2019-01-29    154.68
#   2019-01-30    165.25
#   2019-01-31    166.44
#   Name: close, dtype: float64),
#  (Timestamp('2019-02-28 00:00:00', freq='M'),
#   date
#   2019-02-01    166.52
#   2019-02-04    171.25
#   2019-02-05    174.18
#   2019-02-06    174.24
#   2019-02-07    170.94
#   2019-02-08    170.41
#   2019-02-11    169.43
#   2019-02-12    170.89
#   2019-02-13    170.18
#   2019-02-14    170.80
#   2019-02-15    170.42
#   2019-02-19    170.93
#   2019-02-20    172.03
#   2019-02-21    171.06
#   2019-02-22    172.97
#   2019-02-25    174.23
#   2019-02-26    174.33
#   2019-02-27    174.87
#   2019-02-28    173.15
#   Name: close, dtype: float64),
#  (Timestamp('2019-03-31 00:00:00', freq='M'),
#   date
#   2019-03-01    174.97
#   2019-03-04    175.85
#   2019-03-05    175.53
#   2019-03-06    174.52
#   2019-03-07    172.50
#   2019-03-08    172.91
#   2019-03-11    178.90
#   2019-03-12    180.91
#   2019-03-13    181.71
#   2019-03-14    183.73
#   2019-03-15    186.12
#   2019-03-18    188.02
#   2019-03-19    186.53
#   2019-03-20    188.16
#   2019-03-21    195.09
#   2019-03-22    191.05
#   2019-03-25    188.74
#   2019-03-26    186.79
#   2019-03-27    188.47
#   2019-03-28    188.72
#   2019-03-29    189.95
#   Name: close, dtype: float64),
#  (Timestamp('2019-04-30 00:00:00', freq='M'),
#   date
#   2019-04-01    191.24
#   2019-04-02    194.02
#   2019-04-03    195.35
#   2019-04-04    195.69
#   2019-04-05    197.00
#   2019-04-08    200.10
#   2019-04-09    199.50
#   2019-04-10    200.62
#   2019-04-11    198.95
#   2019-04-12    198.87
#   2019-04-15    199.23
#   2019-04-16    199.25
#   2019-04-17    203.13
#   2019-04-18    203.86
#   2019-04-22    204.53
#   2019-04-23    207.48
#   2019-04-24    207.16
#   2019-04-25    205.28
#   2019-04-26    204.30
#   2019-04-29    204.61
#   2019-04-30    200.67
#   Name: close, dtype: float64),
#  (Timestamp('2019-05-31 00:00:00', freq='M'),
#   date
#   2019-05-01    210.52
#   2019-05-02    209.15
#   2019-05-03    211.75
#   2019-05-06    208.48
#   2019-05-07    202.86
#   2019-05-08    202.90
#   2019-05-09    200.72
#   2019-05-10    197.18
#   2019-05-13    185.72
#   2019-05-14    188.66
#   2019-05-15    190.92
#   2019-05-16    190.08
#   2019-05-17    189.00
#   2019-05-20    183.09
#   2019-05-21    186.60
#   2019-05-22    182.78
#   2019-05-23    179.66
#   2019-05-24    178.97
#   2019-05-28    178.23
#   2019-05-29    177.38
#   2019-05-30    178.30
#   2019-05-31    175.07
#   Name: close, dtype: float64),
#  (Timestamp('2019-06-30 00:00:00', freq='M'),
#   date
#   2019-06-03    173.30
#   2019-06-04    179.64
#   2019-06-05    182.54
#   2019-06-06    185.22
#   2019-06-07    190.15
#   2019-06-10    192.58
#   2019-06-11    194.81
#   2019-06-12    194.19
#   2019-06-13    194.15
#   2019-06-14    192.74
#   2019-06-17    193.89
#   2019-06-18    198.45
#   2019-06-19    197.87
#   2019-06-20    199.46
#   2019-06-21    198.78
#   2019-06-24    198.58
#   2019-06-25    195.57
#   2019-06-26    199.80
#   2019-06-27    199.74
#   2019-06-28    197.92
#   Name: close, dtype: float64),
#  (Timestamp('2019-07-31 00:00:00', freq='M'),
#   date
#   2019-07-01    201.55
#   2019-07-02    202.73
#   2019-07-03    204.41
#   2019-07-05    204.23
#   2019-07-08    200.02
#   2019-07-09    201.24
#   2019-07-10    203.23
#   2019-07-11    201.75
#   2019-07-12    203.30
#   2019-07-15    205.21
#   2019-07-16    204.50
#   2019-07-17    203.35
#   2019-07-18    205.66
#   2019-07-19    202.59
#   2019-07-22    207.22
#   2019-07-23    208.84
#   2019-07-24    208.67
#   2019-07-25    207.02
#   2019-07-26    207.74
#   2019-07-29    209.68
#   2019-07-30    208.78
#   2019-07-31    213.04
#   Name: close, dtype: float64),
#  (Timestamp('2019-08-31 00:00:00', freq='M'),
#   date
#   2019-08-01    208.43
#   2019-08-02    204.02
#   2019-08-05    193.34
#   2019-08-06    197.00
#   2019-08-07    199.04
#   2019-08-08    203.43
#   2019-08-09    200.99
#   2019-08-10    200.99
#   Name: close, dtype: float64)]

# %%
for month_data in list(df.resample("M")):
    s = pd.DataFrame(month_data)
    print(type(month_data),type(s))
# Out:
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>
# <class 'tuple'> <class 'pandas.core.frame.DataFrame'>

# %%
df.close.resample("Q").mean()
# Out:
# date
# 2018-09-30    219.056944
# 2018-12-31    193.912063
# 2019-03-31    169.663770
# 2019-06-30    194.892698
# 2019-09-30    204.066667
# Freq: Q-DEC, Name: close, dtype: float64

# %%
# %matplotlib inline
df.close.resample("M").median().plot()

# %%
df.close.resample("W").mean().plot()

# %%
df.close.resample("D").mean().plot()

# %%
df.close.resample("B").mean().plot()

# %%
Quarterly_resampled_data = df.open.resample('Q').mean().plot()

# %%
period = 15
pd.date_range('2019-02', freq='MS', periods=period)
# Out:
# DatetimeIndex(['2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01',
#                '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01',
#                '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01', '2020-04-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
dr = pd.date_range('2019-02', '2020-08',freq='MS')
print(dr)
len(dr)
# Out:
# DatetimeIndex(['2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01',
#                '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01',
#                '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01',
#                '2020-06-01', '2020-07-01', '2020-08-01'],
#               dtype='datetime64[ns]', freq='MS')
# 19

# %%
pd.date_range('2019-01', freq='B', periods=20)
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18', '2019-01-21', '2019-01-22',
#                '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-28'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range('2019-01', '2019-08',freq='B')
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2019-07-19', '2019-07-22', '2019-07-23', '2019-07-24',
#                '2019-07-25', '2019-07-26', '2019-07-29', '2019-07-30',
#                '2019-07-31', '2019-08-01'],
#               dtype='datetime64[ns]', length=153, freq='B')

# %%
period = 15
x=pd.Series(range(period), index=pd.date_range('2019', freq='MS', periods=period))

# %%
x
# Out:
# 2019-01-01     0
# 2019-02-01     1
# 2019-03-01     2
# 2019-04-01     3
# 2019-05-01     4
# 2019-06-01     5
# 2019-07-01     6
# 2019-08-01     7
# 2019-09-01     8
# 2019-10-01     9
# 2019-11-01    10
# 2019-12-01    11
# 2020-01-01    12
# 2020-02-01    13
# 2020-03-01    14
# Freq: MS, dtype: int64

# %%
from datetime import datetime

# %%
mx=pd.Series(range(3), index=pd.date_range('2019', freq='D', periods=3))
x
# Out:
# 2019-01-01     0
# 2019-02-01     1
# 2019-03-01     2
# 2019-04-01     3
# 2019-05-01     4
# 2019-06-01     5
# 2019-07-01     6
# 2019-08-01     7
# 2019-09-01     8
# 2019-10-01     9
# 2019-11-01    10
# 2019-12-01    11
# 2020-01-01    12
# 2020-02-01    13
# 2020-03-01    14
# Freq: MS, dtype: int64

# %%
df.open.resample('Y').mean().plot()

# %%
df.open.resample('M').mean().plot()

# %%
df.open.resample('M').mean().plot(kind="bar")

# %%
rng=pd.date_range(start="2018-08-09", end="2019/08/09",freq="B")

# %%
rng
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-10', '2018-08-13', '2018-08-14',
#                '2018-08-15', '2018-08-16', '2018-08-17', '2018-08-20',
#                '2018-08-21', '2018-08-22',
#                ...
#                '2019-07-29', '2019-07-30', '2019-07-31', '2019-08-01',
#                '2019-08-02', '2019-08-05', '2019-08-06', '2019-08-07',
#                '2019-08-08', '2019-08-09'],
#               dtype='datetime64[ns]', length=262, freq='B')

# %%
df["2018-12-09" :"2018-08-09"]
# Out:
# Empty DataFrame
# Columns: [close, volume, open, high, low]
# Index: []

# %%
# %matplotlib inline
df["2019-08-01" :"2018-09-01"].close.mean()
# Out:
# nan

# %%
rng=pd.date_range(start="2018-08-09", periods=100,freq="B")

# %%
rng
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-10', '2018-08-13', '2018-08-14',
#                '2018-08-15', '2018-08-16', '2018-08-17', '2018-08-20',
#                '2018-08-21', '2018-08-22', '2018-08-23', '2018-08-24',
#                '2018-08-27', '2018-08-28', '2018-08-29', '2018-08-30',
#                '2018-08-31', '2018-09-03', '2018-09-04', '2018-09-05',
#                '2018-09-06', '2018-09-07', '2018-09-10', '2018-09-11',
#                '2018-09-12', '2018-09-13', '2018-09-14', '2018-09-17',
#                '2018-09-18', '2018-09-19', '2018-09-20', '2018-09-21',
#                '2018-09-24', '2018-09-25', '2018-09-26', '2018-09-27',
#                '2018-09-28', '2018-10-01', '2018-10-02', '2018-10-03',
#                '2018-10-04', '2018-10-05', '2018-10-08', '2018-10-09',
#                '2018-10-10', '2018-10-11', '2018-10-12', '2018-10-15',
#                '2018-10-16', '2018-10-17', '2018-10-18', '2018-10-19',
#                '2018-10-22', '2018-10-23', '2018-10-24', '2018-10-25',
#                '2018-10-26', '2018-10-29', '2018-10-30', '2018-10-31',
#                '2018-11-01', '2018-11-02', '2018-11-05', '2018-11-06',
#                '2018-11-07', '2018-11-08', '2018-11-09', '2018-11-12',
#                '2018-11-13', '2018-11-14', '2018-11-15', '2018-11-16',
#                '2018-11-19', '2018-11-20', '2018-11-21', '2018-11-22',
#                '2018-11-23', '2018-11-26', '2018-11-27', '2018-11-28',
#                '2018-11-29', '2018-11-30', '2018-12-03', '2018-12-04',
#                '2018-12-05', '2018-12-06', '2018-12-07', '2018-12-10',
#                '2018-12-11', '2018-12-12', '2018-12-13', '2018-12-14',
#                '2018-12-17', '2018-12-18', '2018-12-19', '2018-12-20',
#                '2018-12-21', '2018-12-24', '2018-12-25', '2018-12-26'],
#               dtype='datetime64[ns]', freq='B')

# %%
rng=pd.date_range(start="2018-08-09", end="2019/08/09",freq="H")
rng
# Out:
# DatetimeIndex(['2018-08-09 00:00:00', '2018-08-09 01:00:00',
#                '2018-08-09 02:00:00', '2018-08-09 03:00:00',
#                '2018-08-09 04:00:00', '2018-08-09 05:00:00',
#                '2018-08-09 06:00:00', '2018-08-09 07:00:00',
#                '2018-08-09 08:00:00', '2018-08-09 09:00:00',
#                ...
#                '2019-08-08 15:00:00', '2019-08-08 16:00:00',
#                '2019-08-08 17:00:00', '2019-08-08 18:00:00',
#                '2019-08-08 19:00:00', '2019-08-08 20:00:00',
#                '2019-08-08 21:00:00', '2019-08-08 22:00:00',
#                '2019-08-08 23:00:00', '2019-08-09 00:00:00'],
#               dtype='datetime64[ns]', length=8761, freq='H')

# %%
import numpy as np
rng=pd.date_range(start="2018-08-09", end="2019/08/09",freq="H")
rng
x=np.random.randint(1,10,len(rng))
print(x)
# Out:
# [9 8 6 ... 1 8 5]

# %%
ts=pd.Series(np.random.randint(1,10,len(rng)), index=rng)

# %%
ts
# Out:
# 2018-08-09 00:00:00    4
# 2018-08-09 01:00:00    1
# 2018-08-09 02:00:00    5
# 2018-08-09 03:00:00    1
# 2018-08-09 04:00:00    6
#                       ..
# 2019-08-08 20:00:00    2
# 2019-08-08 21:00:00    1
# 2019-08-08 22:00:00    2
# 2019-08-08 23:00:00    8
# 2019-08-09 00:00:00    6
# Freq: H, Length: 8761, dtype: int32

# %%
import numpy as np

# %%
frame = pd.DataFrame({'Humidity':np.arange(50,64)})

frame.loc[[3,7,10,11],'Humidity'] = np.nan
frame['RA'] = frame.Humidity.rolling(4,min_periods=2).mean() 
# print(frame, frame.Humidity.rolling(4,min_periods=1).mean())
frame
# Out:
#     Humidity         RA
# 0       50.0        NaN
# 1       51.0  50.500000
# 2       52.0  51.000000
# 3        NaN  51.000000
# 4       54.0  52.333333
# 5       55.0  53.666667
# 6       56.0  55.000000
# 7        NaN  55.000000
# 8       58.0  56.333333
# 9       59.0  57.666667
# 10       NaN  58.500000
# 11       NaN  58.500000
# 12      62.0  60.500000
# 13      63.0  62.500000

# %%
frame = pd.DataFrame({'Humidity':np.arange(50,64)})

frame.loc[[3,7,10,11],'Humidity'] = np.nan
frame['Humidity_RA'] = frame.Humidity.rolling(4,min_periods=1).mean()
frame['Humidity_w_4'] = frame.Humidity.fillna(frame.Humidity.rolling(4,min_periods=1).mean())
frame['Humidity_w_4_c'] = frame.Humidity.fillna(frame.Humidity.rolling(4,center=True,min_periods=1).mean())
frame['Humidity_w_2'] = frame.Humidity.fillna(frame.Humidity.rolling(2,min_periods=1).mean())
frame['Humidity_w_2_c'] = frame.Humidity.fillna(frame.Humidity.rolling(2,center=True,min_periods=1).mean())
#center='True'
frame
# Out:
#     Humidity  Humidity_RA  Humidity_w_4  Humidity_w_4_c  Humidity_w_2  \
# 0       50.0    50.000000          50.0       50.000000          50.0
# 1       51.0    50.500000          51.0       51.000000          51.0
# 2       52.0    51.000000          52.0       52.000000          52.0
# 3        NaN    51.000000          51.0       52.333333          52.0
# 4       54.0    52.333333          54.0       54.000000          54.0
# 5       55.0    53.666667          55.0       55.000000          55.0
# 6       56.0    55.000000          56.0       56.000000          56.0
# 7        NaN    55.000000          55.0       56.333333          56.0
# 8       58.0    56.333333          58.0       58.000000          58.0
# 9       59.0    57.666667          59.0       59.000000          59.0
# 10       NaN    58.500000          58.5       58.500000          59.0
# 11       NaN    58.500000          58.5       60.500000           NaN
# 12      62.0    60.500000          62.0       62.000000          62.0
# 13      63.0    62.500000          63.0       63.000000          63.0
#
#     Humidity_w_2_c
# 0             50.0
# 1             51.0
# 2             52.0
# 3             52.0
# 4             54.0
# 5             55.0
# 6             56.0
# 7             56.0
# 8             58.0
# 9             59.0
# 10            59.0
# 11             NaN
# 12            62.0
# 13            63.0

# %%
frame = pd.DataFrame({'Humidity':np.arange(50,64)})

frame.loc[[0,7,10,11],'Humidity'] = np.nan
# print(frame)
frame['Humidity_inter'] = frame['Humidity'].interpolate(method='linear',limit_direction='both')
frame
# Out:
#     Humidity  Humidity_inter
# 0        NaN            51.0
# 1       51.0            51.0
# 2       52.0            52.0
# 3       53.0            53.0
# 4       54.0            54.0
# 5       55.0            55.0
# 6       56.0            56.0
# 7        NaN            57.0
# 8       58.0            58.0
# 9       59.0            59.0
# 10       NaN            60.0
# 11       NaN            61.0
# 12      62.0            62.0
# 13      63.0            63.0

# %%
frame = pd.DataFrame({'Humidity':np.arange(50,64)})

frame.loc[[3,7,10,11],'Humidity'] = np.nan
# print(frame)
frame['Humidity_backfill'] = frame['Humidity'].fillna(value=None, method='backfill', axis=None, limit=None, downcast=None)
frame
# Out:
#     Humidity  Humidity_backfill
# 0       50.0               50.0
# 1       51.0               51.0
# 2       52.0               52.0
# 3        NaN               54.0
# 4       54.0               54.0
# 5       55.0               55.0
# 6       56.0               56.0
# 7        NaN               58.0
# 8       58.0               58.0
# 9       59.0               59.0
# 10       NaN               62.0
# 11       NaN               62.0
# 12      62.0               62.0
# 13      63.0               63.0

# %%
frame = pd.DataFrame({'Humidity':np.arange(50,64)})

frame.loc[[3,7,10,11],'Humidity'] = np.nan
# print(frame)
frame['Humidity_ffill'] = frame['Humidity'].fillna(method='ffill')#value=None, method='ffill', axis=None, limit=None, downcast=None)
frame
# Out:
#     Humidity  Humidity_ffill
# 0       50.0            50.0
# 1       51.0            51.0
# 2       52.0            52.0
# 3        NaN            52.0
# 4       54.0            54.0
# 5       55.0            55.0
# 6       56.0            56.0
# 7        NaN            56.0
# 8       58.0            58.0
# 9       59.0            59.0
# 10       NaN            59.0
# 11       NaN            59.0
# 12      62.0            62.0
# 13      63.0            63.0

# %%
# n=5 # number of points to be checked before and after 
# # Find local peaks
# df['min'] = df.iloc[argrelextrema(df.data.values, np.less_equal, order=n)[0]]['data']
# df['max'] = df.iloc[argrelextrema(df.data.values, np.greater_equal, order=n)[0]]['data']

# %%
frame_new = pd.DataFrame({'Price':np.arange(50,100)})
frame_new.loc[[12,4,45,46,47,34,33],'Price'] = np.nan
frame_new
# Out:
#     Price
# 0    50.0
# 1    51.0
# 2    52.0
# 3    53.0
# 4     NaN
# 5    55.0
# 6    56.0
# 7    57.0
# 8    58.0
# 9    59.0
# 10   60.0
# 11   61.0
# 12    NaN
# 13   63.0
# 14   64.0
# 15   65.0
# 16   66.0
# 17   67.0
# 18   68.0
# 19   69.0
# 20   70.0
# 21   71.0
# 22   72.0
# 23   73.0
# 24   74.0
# 25   75.0
# 26   76.0
# 27   77.0
# 28   78.0
# 29   79.0
# 30   80.0
# 31   81.0
# 32   82.0
# 33    NaN
# 34    NaN
# 35   85.0
# 36   86.0
# 37   87.0
# 38   88.0
# 39   89.0
# 40   90.0
# 41   91.0
# 42   92.0
# 43   93.0
# 44   94.0
# 45    NaN
# 46    NaN
# 47    NaN
# 48   98.0
# 49   99.0

# %% [markdown]
# # Fill missing Values in actual data

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("HistoricalQuotes.csv", parse_dates=["date"], index_col=['date'])

# %%
df.volume = df.volume.str.replace(",","").astype(float)

# %%
df.sort_index(inplace=True)
df.shape
# Out:
# (253, 5)

# %%
df.index
# Out:
# DatetimeIndex(['2018-08-09', '2018-08-10', '2018-08-13', '2018-08-14',
#                '2018-08-15', '2018-08-16', '2018-08-17', '2018-08-20',
#                '2018-08-21', '2018-08-22',
#                ...
#                '2019-07-30', '2019-07-31', '2019-08-01', '2019-08-02',
#                '2019-08-05', '2019-08-06', '2019-08-07', '2019-08-08',
#                '2019-08-09', '2019-08-10'],
#               dtype='datetime64[ns]', name='date', length=253, freq=None)

# %%
# all_days = pd.date_range(df.index.min(), df.index.max(), freq='B')
df1= df.copy()
df1.resample('B').mean()
df1.shape
# Out:
# (253, 5)

# %%
idx = pd.period_range(min(df.index), max(df.index),freq='B')
print(len(idx),df.shape[0])
df1= df.copy()
df1.reindex(idx, fill_value=0)
df1.shape
# Out:
# 263 253
# (253, 5)

# %%
def get_missing_dates(df,actual_dates,freq='B'):
    j=0
    missing_dates = []
    for i in range(len(actual_dates)):
        if actual_dates[i] != df.index[j]:
            print(actual_dates[i],df.index[j])
            missing_dates.append(actual_dates[i])
            i+=1
        else:
            j+=1
            i+=1
    return missing_dates

# %%
# actual_dates = pd.date_range(min(df.index), max(df.index), freq='B')
# print(actual_dates)
# get_missing_dates(df,'B',actual_dates)

# %%
def add_missing_dates(df,freq='B'):
    df.sort_index(inplace=True)
    start = df.index[0]
    end = max(df.index)
    actual_dates = pd.date_range(start,end, freq=freq)
    if ( len(actual_dates) != df.shape[0]):
        missing_dates = get_missing_dates(df,actual_dates,freq)
        df = df.append(pd.DataFrame(index=missing_dates))
        df.sort_index(inplace=True)
    return df,missing_dates

# %%
# def fill_missing values(df):

# %%
df1,missing_dates = add_missing_dates(df,freq='B')
missing_dates = list(map(str,missing_dates))
# print(missing_dates)
df1['open_RA'] = df1.open.rolling(4,min_periods=1).mean()
df1['close_RA'] = df1.close.rolling(4,min_periods=1).mean()
df1['volume_RA'] = df1.volume.rolling(4,min_periods=1).mean()
df1['high_RA'] = df1.high.rolling(4,min_periods=1).mean()
df1['low_RA'] = df1.low.rolling(4,min_periods=1).mean()
for ms_date in missing_dates:
    print(df1.loc[ms_date,:])
# Out:
# 2018-09-03 00:00:00 2018-09-04 00:00:00
# 2018-11-22 00:00:00 2018-11-23 00:00:00
# 2018-12-05 00:00:00 2018-12-06 00:00:00
# 2018-12-25 00:00:00 2018-12-26 00:00:00
# 2019-01-01 00:00:00 2019-01-02 00:00:00
# 2019-01-21 00:00:00 2019-01-22 00:00:00
# 2019-02-18 00:00:00 2019-02-19 00:00:00
# 2019-04-19 00:00:00 2019-04-22 00:00:00
# 2019-05-27 00:00:00 2019-05-28 00:00:00
# 2019-07-04 00:00:00 2019-07-05 00:00:00
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      2.233033e+02
# close_RA     2.252133e+02
# volume_RA    3.964959e+07
# high_RA      2.268733e+02
# low_RA       2.226033e+02
# Name: 2018-09-03 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.827000e+02
# close_RA     1.798733e+02
# volume_RA    4.680058e+07
# high_RA      1.841467e+02
# low_RA       1.790167e+02
# Name: 2018-11-22 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.819000e+02
# close_RA     1.800300e+02
# volume_RA    4.036774e+07
# high_RA      1.825533e+02
# low_RA       1.781700e+02
# Name: 2018-12-05 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.551367e+02
# close_RA     1.514633e+02
# volume_RA    6.568845e+07
# high_RA      1.572733e+02
# low_RA       1.505067e+02
# Name: 2018-12-25 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.572900e+02
# close_RA     1.567067e+02
# volume_RA    4.261628e+07
# high_RA      1.582167e+02
# low_RA       1.537000e+02
# Name: 2019-01-01 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.549267e+02
# close_RA     1.558733e+02
# volume_RA    3.111959e+07
# high_RA      1.571400e+02
# low_RA       1.540802e+02
# Name: 2019-01-21 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.707833e+02
# close_RA     1.704667e+02
# volume_RA    2.292605e+07
# high_RA      1.718138e+02
# low_RA       1.696833e+02
# Name: 2019-02-18 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      2.007067e+02
# close_RA     2.020800e+02
# volume_RA    2.623972e+07
# high_RA      2.029667e+02
# low_RA       1.998967e+02
# Name: 2019-04-19 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      1.815533e+02
# close_RA     1.804700e+02
# volume_RA    2.999766e+07
# high_RA      1.827967e+02
# low_RA       1.796600e+02
# Name: 2019-05-27 00:00:00, dtype: float64
# close                 NaN
# volume                NaN
# open                  NaN
# high                  NaN
# low                   NaN
# open_RA      2.026200e+02
# close_RA     2.028967e+02
# volume_RA    1.853800e+07
# high_RA      2.040208e+02
# low_RA       2.015667e+02
# Name: 2019-07-04 00:00:00, dtype: float64

# %%
 
# frame.Humidity.fillna(frame.Humidity.rolling(4,min_periods=1).mean())
df1['open'] = df1.open.fillna(df1.open.rolling(4,min_periods=1).mean())
df1['close'] = df1.close.fillna(df1.close.rolling(4,min_periods=1).mean())
df1['volume'] = df1.volume.fillna(df1.volume.rolling(4,min_periods=1).mean())
df1['high'] = df1.high.fillna(df1.high.rolling(4,min_periods=1).mean())
df1['low'] = df1.low.fillna(df1.low.rolling(4,min_periods=1).mean())
for ms_date in missing_dates:
    print(df1.loc[ms_date,:])

df1
# Out:
# close        2.252133e+02
# volume       3.964959e+07
# open         2.233033e+02
# high         2.268733e+02
# low          2.226033e+02
# open_RA      2.233033e+02
# close_RA     2.252133e+02
# volume_RA    3.964959e+07
# high_RA      2.268733e+02
# low_RA       2.226033e+02
# Name: 2018-09-03 00:00:00, dtype: float64
# close        1.798733e+02
# volume       4.680058e+07
# open         1.827000e+02
# high         1.841467e+02
# low          1.790167e+02
# open_RA      1.827000e+02
# close_RA     1.798733e+02
# volume_RA    4.680058e+07
# high_RA      1.841467e+02
# low_RA       1.790167e+02
# Name: 2018-11-22 00:00:00, dtype: float64
# close        1.800300e+02
# volume       4.036774e+07
# open         1.819000e+02
# high         1.825533e+02
# low          1.781700e+02
# open_RA      1.819000e+02
# close_RA     1.800300e+02
# volume_RA    4.036774e+07
# high_RA      1.825533e+02
# low_RA       1.781700e+02
# Name: 2018-12-05 00:00:00, dtype: float64
# close        1.514633e+02
# volume       6.568845e+07
# open         1.551367e+02
# high         1.572733e+02
# low          1.505067e+02
# open_RA      1.551367e+02
# close_RA     1.514633e+02
# volume_RA    6.568845e+07
# high_RA      1.572733e+02
# low_RA       1.505067e+02
# Name: 2018-12-25 00:00:00, dtype: float64
# close        1.567067e+02
# volume       4.261628e+07
# open         1.572900e+02
# high         1.582167e+02
# low          1.537000e+02
# open_RA      1.572900e+02
# close_RA     1.567067e+02
# volume_RA    4.261628e+07
# high_RA      1.582167e+02
# low_RA       1.537000e+02
# Name: 2019-01-01 00:00:00, dtype: float64
# close        1.558733e+02
# volume       3.111959e+07
# open         1.549267e+02
# high         1.571400e+02
# low          1.540802e+02
# open_RA      1.549267e+02
# close_RA     1.558733e+02
# volume_RA    3.111959e+07
# high_RA      1.571400e+02
# low_RA       1.540802e+02
# Name: 2019-01-21 00:00:00, dtype: float64
# close        1.704667e+02
# volume       2.292605e+07
# open         1.707833e+02
# high         1.718138e+02
# low          1.696833e+02
# open_RA      1.707833e+02
# close_RA     1.704667e+02
# volume_RA    2.292605e+07
# high_RA      1.718138e+02
# low_RA       1.696833e+02
# Name: 2019-02-18 00:00:00, dtype: float64
# close        2.020800e+02
# volume       2.623972e+07
# open         2.007067e+02
# high         2.029667e+02
# low          1.998967e+02
# open_RA      2.007067e+02
# close_RA     2.020800e+02
# volume_RA    2.623972e+07
# high_RA      2.029667e+02
# low_RA       1.998967e+02
# Name: 2019-04-19 00:00:00, dtype: float64
# close        1.804700e+02
# volume       2.999766e+07
# open         1.815533e+02
# high         1.827967e+02
# low          1.796600e+02
# open_RA      1.815533e+02
# close_RA     1.804700e+02
# volume_RA    2.999766e+07
# high_RA      1.827967e+02
# low_RA       1.796600e+02
# Name: 2019-05-27 00:00:00, dtype: float64
# close        2.028967e+02
# volume       1.853800e+07
# open         2.026200e+02
# high         2.040208e+02
# low          2.015667e+02
# open_RA      2.026200e+02
# close_RA     2.028967e+02
# volume_RA    1.853800e+07
# high_RA      2.040208e+02
# low_RA       2.015667e+02
# Name: 2019-07-04 00:00:00, dtype: float64
#              close      volume     open     high     low     open_RA  \
# 2018-08-09  208.88  23389530.0  207.280  209.780  207.20  207.280000
# 2018-08-10  207.53  24592460.0  207.360  209.100  206.67  207.320000
# 2018-08-13  208.87  25864510.0  207.700  210.952  207.70  207.446667
# 2018-08-14  209.75  20679270.0  210.155  210.560  208.26  208.123750
# 2018-08-15  210.24  28595230.0  209.220  210.740  208.33  208.608750
# ...            ...         ...      ...      ...     ...         ...
# 2019-08-06  197.00  35824790.0  196.310  198.067  194.04  203.432500
# 2019-08-07  199.04  33364400.0  195.410  199.560  193.82  198.810000
# 2019-08-08  203.43  27009520.0  200.200  203.530  199.39  197.477500
# 2019-08-09  200.99  24619750.0  201.300  202.760  199.29  198.305000
# 2019-08-10  200.99  24619446.0  201.230  202.760  199.29  199.535000
#
#               close_RA   volume_RA    high_RA      low_RA
# 2018-08-09  208.880000  23389530.0  209.78000  207.200000
# 2018-08-10  208.205000  23990995.0  209.44000  206.935000
# 2018-08-13  208.426667  24615500.0  209.94400  207.190000
# 2018-08-14  208.757500  23631442.5  210.09800  207.457500
# 2018-08-15  209.097500  24932867.5  210.33800  207.740000
# ...                ...         ...        ...         ...
# 2019-08-06  200.697500  45774450.0  205.29400  198.748375
# 2019-08-07  198.350000  40611070.0  200.67650  195.517500
# 2019-08-08  198.202500  37147920.0  199.95150  194.957500
# 2019-08-09  200.115000  30204615.0  200.97925  196.635000
# 2019-08-10  201.112500  27403279.0  202.15250  197.947500
#
# [263 rows x 10 columns]

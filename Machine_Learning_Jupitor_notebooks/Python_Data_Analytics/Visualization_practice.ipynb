# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
import pandas as pd

# %%
df = pd.read_csv("clean_cervical.csv")

# %%
df.columns, df.shape
# Out:
# (Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#         'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#         'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31',
#         'V32', 'Cancer'],
#        dtype='object'), (858, 33))

# %%
df.describe()
# Out:
#                V1          V2          V3  ...         V31         V32      Cancer
# count  858.000000  858.000000  858.000000  ...  858.000000  858.000000  858.000000
# mean    26.820513    2.511655   16.979021  ...    0.020979    0.027972    0.118881
# std      8.497948    1.644759    2.797653  ...    0.143398    0.164989    0.323837
# min     13.000000    1.000000   10.000000  ...    0.000000    0.000000    0.000000
# 25%     20.000000    2.000000   15.000000  ...    0.000000    0.000000    0.000000
# 50%     25.000000    2.000000   17.000000  ...    0.000000    0.000000    0.000000
# 75%     32.000000    3.000000   18.000000  ...    0.000000    0.000000    0.000000
# max     84.000000   28.000000   32.000000  ...    1.000000    1.000000    1.000000
#
# [8 rows x 33 columns]

# %%
df['V3'].unique(),len(df['V3'].unique())
# Out:
# (array([15, 14, 16, 21, 23, 17, 26, 20, 25, 18, 27, 19, 24, 32, 13, 29, 11,
#         12, 22, 28, 10], dtype=int64),
#  21)

# %%
##import matplotlib.pyplot as plt # is compulsory
df[['V3']].hist() # V3, V24, V7
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f538201c278>]],
#       dtype=object)

# %%
df['V3'].mean(),df['V3'].std()
# Out:
# (16.97902097902098, 2.7976532876464644)

# %%
df[['V3','V7']].hist() # V3, V24, V7
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5381f78e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5381abe390>]],
#       dtype=object)

# %%
df[['V3']].boxplot()

# %%
df.plot.scatter(x='V4',y='V3')

# %%
df_ts = pd.read_csv("AirPassengers.csv")

# %%
df_ts.shape, df_ts.columns
# Out:
# ((144, 2), Index(['Month', 'No_Passengers'], dtype='object'))

# %%
df_ts['No_Passengers'].plot()

# %%
df_ma = pd.read_csv("MarketArrivals.csv")

# %%
df_ma.shape,df_ma.columns
# Out:
# ((10227, 10),
#  Index(['market', 'month', 'year', 'quantity', 'priceMin', 'priceMax',
#         'priceMod', 'state', 'city', 'date'],
#        dtype='object'))

# %%
df_ma = df_ma.select_dtypes(exclude=['object'])

# %%
df_ma.shape,df_ma.columns
# Out:
# ((10227, 5),
#  Index(['year', 'quantity', 'priceMin', 'priceMax', 'priceMod'], dtype='object'))

# %%
df_ma.plot()

# %%
df_ma.describe()
# Out:
#                year      quantity      priceMin      priceMax      priceMod
# count  10227.000000  1.022700e+04  10227.000000  10227.000000  10227.000000
# mean    2009.022294  7.660488e+04    646.944363   1212.760731    984.284345
# std        4.372841  1.244087e+05    673.121850    979.658874    818.471498
# min     1996.000000  2.000000e+01     16.000000    145.000000     80.000000
# 25%     2006.000000  8.898000e+03    209.000000    557.000000    448.000000
# 50%     2009.000000  2.746000e+04    440.000000    923.000000    747.000000
# 75%     2013.000000  8.835650e+04    828.000000   1527.000000   1248.000000
# max     2016.000000  1.639032e+06   6000.000000   8192.000000   6400.000000

# %%
df_ma[['year', 'priceMin', 'priceMax', 'priceMod']].plot()

# %%
df_ma[['priceMin', 'priceMax', 'priceMod']].plot()

# %%
df_ma[['priceMin', 'priceMax']].plot()

# %%
df['Cancer'].value_counts().plot.pie()

# %%
import seaborn as sb

# %%
# from matplotlib import pyplot as plt
df_sb = sb.load_dataset('tips')
sb.violinplot(x = "day", y = "total_bill", data=df_sb)
plt.show()

# %%
sb.violinplot(x = "priceMin", data=df_ma)
plt.show()

# %%
sb.violinplot(x='V2',y='V3', data=df)
plt.show()

# %%
df[['V2','V3']].describe()
# Out:
#                V2          V3
# count  858.000000  858.000000
# mean     2.511655   16.979021
# std      1.644759    2.797653
# min      1.000000   10.000000
# 25%      2.000000   15.000000
# 50%      2.000000   17.000000
# 75%      3.000000   18.000000
# max     28.000000   32.000000

# %%
from statsmodels.graphics.mosaicplot import mosaic
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#V24 V25
mosaic(df, ['V4', 'V24'], title='Mosaic')
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  OrderedDict([(('1', '0'),
#                (0.0, 0.0, 0.36186036186036186, 0.9936204471801561)),
#               (('1', '1'),
#                (0.0,
#                 0.9969427063163687,
#                 0.36186036186036186,
#                 0.003057293683631232)),
#               (('4', '0'),
#                (0.3666222666222666,
#                 0.0,
#                 0.0821400821400821,
#                 0.9966777408637874)),
#               (('4', '1'), (0.3666222666222666, 1.0, 0.0821400821400821, 0.0)),
#               (('2', '0'),
#                (0.4535242535242535,
#                 0.0,
#                 0.2664002664002665,
#                 0.9966777408637874)),
#               (('2', '1'), (0.4535242535242535, 1.0, 0.2664002664002665, 0.0)),
#               (('6', '0'),
#                (0.7246864246864247,
#                 0.0,
#                 0.01998001998001994,
#                 0.9966777408637874)),
#               (('6', '1'),
#                (0.7246864246864247, 1.0, 0.01998001998001994, 0.0)),
#               (('3', '0'),
#                (0.7494283494283495,
#                 0.0,
#                 0.1542901542901543,
#                 0.9966777408637874)),
#               (('3', '1'), (0.7494283494283495, 1.0, 0.1542901542901543, 0.0)),
#               (('5', '0'),
#                (0.9084804084804085,
#                 0.0,
#                 0.038850038850038855,
#                 0.9966777408637874)),
#               (('5', '1'),
#                (0.9084804084804085, 1.0, 0.038850038850038855, 0.0)),
#               (('8', '0'),
#                (0.9520923520923521,
#                 0.0,
#                 0.0022200022200021445,
#                 0.9966777408637874)),
#               (('8', '1'),
#                (0.9520923520923521, 1.0, 0.0022200022200021445, 0.0)),
#               (('7', '0'),
#                (0.959074259074259,
#                 0.0,
#                 0.006660006660006751,
#                 0.9966777408637874)),
#               (('7', '1'),
#                (0.959074259074259, 1.0, 0.006660006660006751, 0.0)),
#               (('0', '0'),
#                (0.9704961704961704,
#                 0.0,
#                 0.017760017760017687,
#                 0.9966777408637874)),
#               (('0', '1'),
#                (0.9704961704961704, 1.0, 0.017760017760017687, 0.0)),
#               (('11', '0'),
#                (0.9930180930180929,
#                 0.0,
#                 0.0011100011100011252,
#                 0.9966777408637874)),
#               (('11', '1'),
#                (0.9930180930180929, 1.0, 0.0011100011100011252, 0.0)),
#               (('10', '0'),
#                (0.9988899988899989,
#                 0.0,
#                 0.0011100011100011252,
#                 0.9966777408637874)),
#               (('10', '1'),
#                (0.9988899988899989, 1.0, 0.0011100011100011252, 0.0))]))

# %%
df.plot.scatter(x='V4',y='V24')

# %%
from sklearn.cluster import KMeans
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np

# %%
from sklearn.datasets.samples_generator import make_blobs
X, y_true = make_blobs(n_samples=300, \
                       centers=4,\
                       cluster_std=0.60,\
                       random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);
# Out:
# D:\Installed_new\Anaconda\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
y_kmeans = kmeans.predict(X)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_kmeans, s=50, cmap='viridis')

centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
X = StandardScaler().fit_transform(X)

# %%
y_pred = DBSCAN(eps=0.3, min_samples=10).fit_predict(X)
print('Number of clusters: {}'.format(len(set(y_pred[np.where(y_pred != -1)]))))
print('Outliers :', len(y_pred[np.where(y_pred == -1)]))
plt.scatter(X[:,0], X[:,1], c=y_pred)
# Out:
# Number of clusters: 4
# Outliers : 22

# %%
y_pred = DBSCAN(eps=0.65, min_samples=10).fit_predict(X)
print('Number of clusters: {}'.format(len(set(y_pred[np.where(y_pred != -1)]))))
print('Outliers :', len(y_pred[np.where(y_pred == -1)]))
plt.scatter(X[:,0], X[:,1], c=y_pred)
# Out:
# Number of clusters: 1
# Outliers : 0

# %%
y_pred = DBSCAN(eps=0.1, min_samples=10).fit_predict(X)
print('Number of clusters: {}'.format(len(set(y_pred[np.where(y_pred != -1)]))))
print('Outliers :', len(y_pred[np.where(y_pred == -1)]))
plt.scatter(X[:,0], X[:,1], c=y_pred)
# Out:
# Number of clusters: 1
# Outliers : 288

# %%
y_pred = DBSCAN(eps=0.3, min_samples=25).fit_predict(X)
print('Number of clusters: {}'.format(len(set(y_pred[np.where(y_pred != -1)]))))
print('Outliers :', len(y_pred[np.where(y_pred == -1)]))
plt.scatter(X[:,0], X[:,1], c=y_pred)
# Out:
# Number of clusters: 4
# Outliers : 77

# %%
y_pred = DBSCAN(eps=0.3, min_samples=3).fit_predict(X)
print('Number of clusters: {}'.format(len(set(y_pred[np.where(y_pred != -1)]))))
print('Outliers :', len(y_pred[np.where(y_pred == -1)]))
plt.scatter(X[:,0], X[:,1], c=y_pred)
# Out:
# Number of clusters: 4
# Outliers : 2

# %%
from sklearn.datasets import load_digits
digits = load_digits()
digits.data.shape
# Out:
# (1797, 64)

# %%
kmeans = KMeans(n_clusters=10, random_state=0)
clusters = kmeans.fit_predict(digits.data)
kmeans.cluster_centers_.shape
# Out:
# (10, 64)

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
centers = kmeans.cluster_centers_.reshape(10, 8, 8)
for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='nearest', cmap=plt.cm.binary)

# %%
plt.imshow(digits.data[50].reshape(8, 8))

# %%
kmeans.predict(digits.data[50].reshape(1,64))[0]
# Out:
# 7

# %%
digits.target[50]
# Out:
# 2
